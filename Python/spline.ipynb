# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
# Define the data points (time in hours, temperature in degrees Celsius)
time = [0, 3, 6, 9, 12, 15, 18, 21, 24]
temperature = [15, 17, 19, 22, 25, 23, 20, 18, 16]
dta = pd.DataFrame({'time': time, 'temperature': temperature})
display(dta)
# Out:
#    time  temperature
# 0     0           15
# 1     3           17
# 2     6           19
# 3     9           22
# 4    12           25
# 5    15           23
# 6    18           20
# 7    21           18
# 8    24           16

# %%
# Create a cubic spline interpolation of the data
cs = CubicSpline(dta['time'], dta['temperature'])

# Define a range of time values for plotting the smooth curve
time_smooth = np.linspace(0, 24, 500)
temperature_smooth = cs(time_smooth)

# %%
# Plot the original data points and the interpolated curve
plt.figure(figsize=(10, 6))
plt.plot(time, temperature, 'o', label='Data Points')
plt.plot(time_smooth, temperature_smooth, '-', label='Cubic Spline Interpolation')
plt.xlabel('Time (hours)')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Throughout the Day')
plt.legend()
plt.grid(True)
plt.show()
